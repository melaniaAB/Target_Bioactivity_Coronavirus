# %% [markdown]
# # Computational Drug Discovery
# ## **ChEMBL Database**
# ##### version 26

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %% [markdown]
# ## **Import libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
#
#                                            pref_name  score  \
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# The fifth entry, corresponding to the target protein, *Human Acetylcholinesterase* is assigned to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL613732'

# %% [markdown]
# Only the boactivity data for *Human Acetylcholinesterase* (CHEMBL220) is selected/obtained.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# Drop missing data for any compounds containing columns with missing value for the **standard_value** and **canonical_smiles**.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
# Out:
# <ipython-input-39-de532c672fb8>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]

# %%
df2
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7021             None     18798886                  []   CHEMBL4274263
# 7022             None     18798887                  []   CHEMBL4274263
# 7023             None     18798888                  []   CHEMBL4274263
# 7024             None     18798889                  []   CHEMBL4274263
# 7025             None     18798890                  []   CHEMBL4274263
#
#                                       assay_description assay_type  \
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 4695

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7019             None     18798884                  []   CHEMBL4274263
# 7020             None     18798885                  []   CHEMBL4274263
# 7021             None     18798886                  []   CHEMBL4274263
# 7022             None     18798887                  []   CHEMBL4274263
# 7023             None     18798888                  []   CHEMBL4274263
#
#                                       assay_description assay_type  \
# ...

# %% [markdown]
# ## **Data pre-processing for the bioactivity data**

# %% [markdown]
# #### **Keep the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class save into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 7019      CHEMBL4293155  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccccc3Cl)CC...
# 7020      CHEMBL4282558  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc(Cl)c3)...
# 7021      CHEMBL4281727  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(Br)cc3)...
# 7022      CHEMBL4292349  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc([N+](=...
# 7023      CHEMBL4278260  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(C#N)cc3...
#
#      standard_value
# 0             750.0
# 1             100.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds with the values of < 1000 nM will be considered **active**, while those > 10,000 nM will be considered **inactive**. And compounds with values in between 1,000 and 10,000 nM will be considered as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 4690      CHEMBL4293155  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccccc3Cl)CC...
# 4691      CHEMBL4282558  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc(Cl)c3)...
# 4692      CHEMBL4281727  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(Br)cc3)...
# 4693      CHEMBL4292349  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3cccc([N+](=...
# 4694      CHEMBL4278260  CC(C)(C)c1cc(/C=C/C(=O)NCCC2CCN(Cc3ccc(C#N)cc3...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe 5 to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
#!7z a -tzip acetylcholinesterase.zip *.csv

# %%
! ls -l *.csv
# Out:
# -rw-r--r-- 1 Melania 197121  460676 Oct 22 03:04 House_Price_train.csv
# -rw-r--r-- 1 Melania 197121 3569897 Oct 27 03:34 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 Melania 197121  347685 Oct 27 03:40 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 Melania 197121  390620 Oct 27 03:42 acetylcholinesterase_03_bioactivity_data_curated.csv

# %% [markdown]
# ---
